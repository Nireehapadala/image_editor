# %%
-from matplotlib import pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
img_path = '/content/dd1.jpg'
img=load_img(img_path)
img_array=img_to_array(img)
img_array=img_array.reshape((1,) + img_array.shape)
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    # Corrected the typo in the keyword argument
    horizontal_flip=True,
    fill_mode='nearest'
)
augmented_images = datagen.flow(img_array, batch_size=1)
def visualize_augmented_images(generator,num_images):
  fix,ages = plt.subplots(1,num_images,figsize=(20,20))
  for i in range(num_images):
    batch=next(generator)
    aug_img=batch[0]
    ages[i].imshow(img_to_array(aug_img))
    ages[i].axis('off')

plt.show()
visualize_augmented_images(augmented_images, 10)

# %%
original=img_array[0]/255.0
from typing import Generator
import matplotlib.pyplot as plt # Import pyplot

# Define the number of pairs you want to display
num_pairs = 5 # You can change this number as needed

# Create a figure and axes to display the image pairs
# We need num_pairs rows and 2 columns (original and augmented)
fig, axes = plt.subplots(num_pairs, 2, figsize=(10, 5 * num_pairs))


for i in range(num_pairs):
  # It seems you intended to use the 'augmented_images' generator here,
  # not the 'Generator' type from typing.
  batch=next(augmented_images)
  aug_image=batch[0]

  axes[i,0].imshow(original)
  axes[i,0].set_title('original')
  axes[i,0].axis('off')

  axes[i,1].imshow(aug_image) # Corrected 'inshow' to 'imshow'
  axes[i,1].set_title('augmented')
  axes[i,1].axis('off')

plt.tight_layout()
plt.show()
